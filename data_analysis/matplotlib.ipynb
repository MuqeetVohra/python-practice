# %%
# importing liberaries
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)
z = np.cos(x)

# %%
# plotting the data
# sin wave
plt.plot(x,y)

# %%
# cos wave
plt.plot(x, z)

# %%
# adding title x-axis & y axis labels
plt.plot(x, y)
plt.xlabel('Angle')
plt.ylabel('Sine value')
plt.title('Sine Wave')
# Out:
# Text(0.5, 1.0, 'Sine Wave')

# %%
# parabola
x = np.linspace(-10, 10, 20)
y = x**2

plt.plot(x, y)

# %%
plt.plot(x, y, 'r+')

# %%
plt.plot(x, y, 'g.')

# %%
plt.plot(x, y, 'rx')

# %%
x = np.linspace(-5, 5, 50)
plt.plot(x, np.sin(x), 'g-')
plt.plot(x, np.cos(x), 'r--')
plt.legend(['Sin', 'Cos'])

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
languages = ['English', 'French', 'Spanish', 'Latin', 'German']
people = [100, 50, 150, 40, 70]
ax.bar(languages, people)
plt.xlabel('Languages')
plt.ylabel('No. of People')
plt.show()

# %%
fig1 = plt.figure()
ax = fig1.add_axes([0, 0, 1, 1])
languages = ['English', 'French', 'Spanish', 'Latin', 'German']
people = [100, 50, 150, 40, 70]
ax.pie(people, labels=languages, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x278fd661810>,
#   <matplotlib.patches.Wedge at 0x278fd661bd0>,
#   <matplotlib.patches.Wedge at 0x278fd661f90>,
#   <matplotlib.patches.Wedge at 0x278fd662350>,
#   <matplotlib.patches.Wedge at 0x278fd662710>],
#  [Text(0.7925737256074618, 0.7627757792934357, 'English'),
#   Text(-0.37181872076672423, 1.035253997281535, 'French'),
#   Text(-1.048735997484725, -0.33189276518134464, 'Spanish'),
#   Text(0.2094304679201163, -1.079879103930973, 'Latin'),
#   Text(0.9455267523746521, -0.5621202367321811, 'German')],
#  [Text(0.4323129412404336, 0.4160595159782376, '24.4%'),
#   Text(-0.2028102113273041, 0.564683998517201, '12.2%'),
#   Text(-0.5720378168098499, -0.1810324173716425, '36.6%'),
#   Text(0.11423480068369979, -0.5890249657805307, '9.8%'),
#   Text(0.5157418649316284, -0.3066110382175533, '17.1%')])
